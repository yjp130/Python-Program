# %%
import pandas as pd

# %%
train=pd.read_csv("california_housing_train.csv")
test=pd.read_csv("california_housing_test.csv")

# %%
# Out:
# (17000, 9)

# %%
print(train.shape)
print(train.columns)
print(train.info())
print(train.describe())
print(train.isnull().sum())
# Out:
# (17000, 9)
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
# longitude             17000 non-null float64
# latitude              17000 non-null float64
# housing_median_age    17000 non-null float64
# total_rooms           17000 non-null float64
# total_bedrooms        17000 non-null float64
# population            17000 non-null float64
# households            17000 non-null float64
# median_income         17000 non-null float64
# median_house_value    17000 non-null float64
# dtypes: float64(9)
# memory usage: 1.2 MB
# None
#           longitude      latitude  ...  median_income  median_house_value
# count  17000.000000  17000.000000  ...   17000.000000        17000.000000
# ...

# %%
train.loc[100:103]
# Out:
#      longitude  latitude  ...  median_income  median_house_value
# 100    -115.59     32.79  ...         6.3814            159900.0
# 101    -115.59     32.69  ...         2.5769             94400.0
# 102    -115.60     33.20  ...         2.4511             72500.0
# 103    -115.60     32.87  ...         4.1293             83200.0
#
# [4 rows x 9 columns]

# %%
train.iloc[100:111,:]
# Out:
#      longitude  latitude  ...  median_income  median_house_value
# 100    -115.59     32.79  ...         6.3814            159900.0
# 101    -115.59     32.69  ...         2.5769             94400.0
# 102    -115.60     33.20  ...         2.4511             72500.0
# 103    -115.60     32.87  ...         4.1293             83200.0
# 104    -115.62     33.04  ...         2.2969             62000.0
# 105    -115.62     33.04  ...         2.0463             61200.0
# 106    -115.64     32.80  ...         3.1667            125000.0
# 107    -115.69     32.79  ...         2.1792             55200.0
# 108    -115.72     32.75  ...         2.0938             87500.0
# 109    -115.73     33.36  ...         1.7727             50000.0
# 110    -115.73     33.35  ...         1.2132             30000.0
#
# [11 rows x 9 columns]

# %%
train.sort_values(by='latitude')
# Out:
#        longitude  latitude  ...  median_income  median_house_value
# 680      -117.04     32.54  ...         1.2667             67500.0
# 796      -117.06     32.55  ...         1.4384            108800.0
# 995      -117.09     32.55  ...         3.9583            144400.0
# 679      -117.04     32.55  ...         1.6348             93200.0
# 1161     -117.12     32.56  ...         2.9286            257700.0
# 737      -117.05     32.56  ...         2.0159            139300.0
# 464      -116.97     32.56  ...         2.5625            153300.0
# 860      -117.07     32.56  ...         3.0992            142600.0
# 739      -117.05     32.56  ...         2.8750            134500.0
# 738      -117.05     32.56  ...         1.9875            114900.0
# 1048     -117.10     32.56  ...         3.7500            146800.0
# 795      -117.06     32.56  ...         1.7958            140400.0
# 794      -117.06     32.56  ...         1.7301            125000.0
# ...

# %%
# train.iloc[ 100:111 ,  0:2 ]
range_num = list(range(100, 111, 1))
range_num
train.loc[ range_num , ['longitude', 'latitude'] ]
# Out:
#      longitude  latitude
# 100    -115.59     32.79
# 101    -115.59     32.69
# 102    -115.60     33.20
# 103    -115.60     32.87
# 104    -115.62     33.04
# 105    -115.62     33.04
# 106    -115.64     32.80
# 107    -115.69     32.79
# 108    -115.72     32.75
# 109    -115.73     33.36
# 110    -115.73     33.35

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
### 위도 경도에 따른 산점도 분포
train.plot(kind="scatter", x="longitude", y="latitude",
alpha=0.4, s=train["population"]/100,
label="population", c="median_house_value",
figsize=(12,8),
cmap=plt.get_cmap("jet"), colorbar=True)

# %%
plt.figure(figsize=(10,10))
plt.subplot(3,1,1)
sns.boxplot(x="total_rooms", data=train)
plt.subplot(3,1,2)
sns.boxplot(x="total_bedrooms", data=train)
plt.subplot(3,1,3)
sns.boxplot(x="population", data=train)

# %%
sel = ['total_rooms', 'total_bedrooms', 'population']
temp_train = train[ sel ]
print("데이터 가공 셋의 크기 : ", train.shape)
print("데이터 가공 셋의 일부 : ", train.head)
# Out:
# 데이터 가공 셋의 크기 :  (17000, 9)
# 데이터 가공 셋의 일부 :  <bound method NDFrame.head of        longitude  latitude  ...  median_income  median_house_value
# 0        -114.31     34.19  ...         1.4936             66900.0
# 1        -114.47     34.40  ...         1.8200             80100.0
# 2        -114.56     33.69  ...         1.6509             85700.0
# 3        -114.57     33.64  ...         3.1917             73400.0
# 4        -114.57     33.57  ...         1.9250             65500.0
# 5        -114.58     33.63  ...         3.3438             74000.0
# 6        -114.58     33.61  ...         2.6768             82400.0
# 7        -114.59     34.83  ...         1.7083             48500.0
# 8        -114.59     33.61  ...         2.1782             58400.0
# 9        -114.60     34.83  ...         2.1908             48100.0
# 10       -114.60     33.62  ...         2.6797             86500.0
# 11       -114.60     33.60  ...         1.6250             62000.0
# ...

# %%
#실습5-1

idx=range(6,8)
dat=train.iloc[:,idx]
dat
# Out:
#        households  median_income
# 0           472.0         1.4936
# 1           463.0         1.8200
# 2           117.0         1.6509
# 3           226.0         3.1917
# 4           262.0         1.9250
# 5           239.0         3.3438
# 6           633.0         2.6768
# 7           158.0         1.7083
# 8          1056.0         2.1782
# 9           271.0         2.1908
# 10          824.0         2.6797
# 11          437.0         1.6250
# 12          211.0         2.1571
# 13          479.0         3.2120
# 14          300.0         0.8585
# 15          401.0         1.6991
# 16          256.0         2.9653
# 17           27.0         0.8571
# 18          320.0         1.2049
# 19           15.0         1.2656
# 20          303.0         1.6395
# 21          139.0         0.8964
# 22           58.0         1.6250
# 23           52.0         3.2097
# 24          283.0         1.6250
# 25           89.0         3.6528
# 26          335.0         3.5735
# ...

# %%
#실습5-2

idx=range(0,8,2)
dat=train.iloc[:,idx]
dat
# Out:
#        longitude  housing_median_age  total_bedrooms  households
# 0        -114.31                15.0          1283.0       472.0
# 1        -114.47                19.0          1901.0       463.0
# 2        -114.56                17.0           174.0       117.0
# 3        -114.57                14.0           337.0       226.0
# 4        -114.57                20.0           326.0       262.0
# 5        -114.58                29.0           236.0       239.0
# 6        -114.58                25.0           680.0       633.0
# 7        -114.59                41.0           168.0       158.0
# 8        -114.59                34.0          1175.0      1056.0
# 9        -114.60                46.0           309.0       271.0
# 10       -114.60                16.0           801.0       824.0
# 11       -114.60                21.0           483.0       437.0
# 12       -114.61                48.0           248.0       211.0
# ...
