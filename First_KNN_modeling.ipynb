# %%
import sys
import pandas as pd
import matplotlib.pyplot as plt
import numpy as  np
import scipy as sp
import seaborn as sns

# %%
from sklearn.datasets import load_iris
iris=load_iris()
iris
type(iris)
iris.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
#% 데이터 셋 확인
iris.target.shape
iris.data.shape
iris['feature_names']
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
# 훈련 데이터 테스트 데이터 나누기
#train_test_split(문제, 답, random_state=0)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(iris['data'],
                                                  iris['target'],
                                                  random_state=0)

# %%
#% 시각화 matplotlib, seaborn, pandas
import seaborn as sns

#series는 list형태로, dictionary는 dataframe으로 들어간다

iris_df=pd.DataFrame(X_train, columns=iris.feature_names)
iris_df['y']=y_train
iris_df['y']=iris_df['y'].astype('category') #범주형으로 바꾸기

# %%
sns.pairplot(iris_df.iloc[:,0:4]) #인덱스로 선택해서 값을 가지고 오기, loc는 그냥 값을 갖고오기

# %%
pd.plotting.scatter_matrix(iris_df, c=y_train, #색
                          figsize=(15,15), #크기
                          marker='o',
                          hist_kwds={'bins':20}, #막대
                          s=60, #size
                          alpha=0.8) #투명도
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E2BDCD6DD8>,
# ...
#       dtype=object)

# %%
#knn 모델 (지도학습)
#훈련데이터에서 새로운 데이터 포인트에 가장 가까운 'k개'의 이웃을 찾는다
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=1)
knn

#학습
knn.fit(X_train, y_train)

print(type(X_train)) #numpy.ndarry
print(type(y_train))

#예측
X_new= np.array([[5, 2.9, 1, 0.2 ]])

pred=knn.predict(X_new)
pred

y_train
pred_targetname=iris['target_names'][pred]
pred_targetname
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# array(['setosa'], dtype='<U10')

# %%
#평가
print("테스트 세트의 정확도: {:.2f}".format(np.mean(y_pred )))
print("테스트 세트의 정확도: %.2f")
