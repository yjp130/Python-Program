# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

number_of_points = 200
x_point = []
y_point = []

w = 0.25
b = 0.75

for i in range(number_of_points):
    x = np.random.normal(0.0, 0.5)
    y = w*x + b +np.random.normal(0.0, 0.1)
    x_point.append([x])
    y_point.append([y])

# %%
plt.plot(x_point,y_point, 'o', label='Input Data')
plt.legend(loc=4)
plt.show()

# %%
W=tf.Variable(tf.random_uniform([1],-1.0,1.0))
B=tf.Variable(tf.zeros([1]))
y=W*x_point+B

#computes the mean of elements across dimensions of a ensor
cost_function=tf.reduce_mean(tf.square(y-y_point))

#Optimizer that implements the gradient descent algorithm
optimizer=tf.train.GradientDescentOptimizer(learning_rate=0.5)

#Add operations to minimize cost_function
train=optimizer.minimize(cost_function)

#Returns an Op that initializes global variables
model=tf.global_variables_initializer()

# %%
with tf.Session() as sess:
    sess.run(model)
    for step in range(0,2001):
        sess.run(train)
        if (step % 200) == 0 or step<5:
            print("\n y = {w} x + {b} ".format(w=sess.run(W), b=sess.run(B)))
            plt.plot(x_point,y_point,'o',label='step = {}'.format(step))
            plt.plot(x_point,sess.run(W)*x_point+sess.run(B))
            plt.legend(loc=2)
            plt.show()
# Out:
#  y = [0.34717456] x + [0.743956]
#  y = [0.3242619] x + [0.74193823]
#  y = [0.30704266] x + [0.7412]
#  y = [0.2941272] x + [0.7406452]
#  y = [0.28443977] x + [0.740229]
#  y = [0.2553678] x + [0.7389801]
#  y = [0.2553678] x + [0.7389801]
#  y = [0.2553678] x + [0.7389801]
#  y = [0.2553678] x + [0.7389801]
#  y = [0.2553678] x + [0.7389801]
#  y = [0.2553678] x + [0.7389801]
#  y = [0.2553678] x + [0.7389801]
#  y = [0.2553678] x + [0.7389801]
#  y = [0.2553678] x + [0.7389801]
#  y = [0.2553678] x + [0.7389801]
